# %%
# Importing the libraries 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
# Importing the dataset 
datas = pd.read_csv('twt.csv') 
datas
# Out:
#      Unnamed: 0   index                                               text  \
# 0             0     1.0  RT @RNTata2000: The governments bold implemen...
# 1             1     2.0  RT @OfficeOfRG: Fully prepared for demonetizat...
# 2             2     3.0  RT @RNTata2000: Some further thoughts on imple...
# 3             3     4.0  RT @OfficeOfRG: The Congress Party's Charter o...
# 4             4     5.0  RT @scotchism: Hahaha...cutest critique of dem...
# 5             5     6.0  RT @prashantktm: Voices from the ground in UP ...
# 6             6     7.0  RT @bhaiyyajispeaks: Here @sardesairajdeep str...
# 7             7     8.0  RT @manoharparrikar: Demonetization has struck...
# 8             8     9.0  RT @URautelaForever: Dear @evanspiegel \r\r\nI...
# 9             9    10.0  Dear @evanspiegel \r\r\nIndia is so rich that ...
# 10           10    11.0  RT @RealHistoryPic: Can't say anything about P...
# ...

# %%
datas.head()
# Out:
#   Unnamed: 0  index                                               text  \
# 0          0    1.0  RT @RNTata2000: The governments bold implemen...
# 1          1    2.0  RT @OfficeOfRG: Fully prepared for demonetizat...
# 2          2    3.0  RT @RNTata2000: Some further thoughts on imple...
# 3          3    4.0  RT @OfficeOfRG: The Congress Party's Charter o...
# 4          4    5.0  RT @scotchism: Hahaha...cutest critique of dem...
#
#    retweetCount  polarityScore
# 0        5170.0            4.0
# 1        3754.0            1.0
# 2        2507.0            0.0
# 3        2092.0           -1.0
# 4        2037.0            1.0

# %%
X = datas.iloc[:, 3].values 
y = datas.iloc[:, 4].values

# %%
X=X.reshape(-1,1)

# %%
datas.retweetCount
# Out:
# 0       5170.0
# 1       3754.0
# 2       2507.0
# 3       2092.0
# 4       2037.0
# 5       1944.0
# 6       1868.0
# 7       1443.0
# 8       1333.0
# 9       1333.0
# 10      1158.0
# 11      1104.0
# 12      1062.0
# 13      1057.0
# 14      1042.0
# 15      1030.0
# 16      1010.0
# 17       960.0
# 18       954.0
# 19       947.0
# 20       912.0
# 21       897.0
# 22       894.0
# 23       886.0
# 24       862.0
# 25       762.0
# 26       661.0
# 27       637.0
# 28       637.0
# 29       635.0
#          ...
# 5149       0.0
# 5150       0.0
# 5151       0.0
# 5152       0.0
# 5153       0.0
# 5154       0.0
# 5155       0.0
# 5156       0.0
# 5157       0.0
# 5158       0.0
# 5159       0.0
# 5160       0.0
# 5161       0.0
# 5162       0.0
# 5163       0.0
# 5164       0.0
# 5165       0.0
# 5166       0.0
# 5167       0.0
# 5168       0.0
# 5169       0.0
# 5170       0.0
# 5171       0.0
# 5172       0.0
# 5173       0.0
# 5174       0.0
# 5175       0.0
# ...

# %%
for i in range(0,5179):
    X[i]=X[i]/5170
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-85-68089e4588bf> in <module>()
#       1 for i in range(0,5179):
# ----> 2     X[i]=X[i]/5170
#
# IndexError: index 5171 is out of bounds for axis 0 with size 5171

# %%
datas.polarityScore
# Out:
# 0       4.0
# 1       1.0
# 2       0.0
# 3      -1.0
# 4       1.0
# 5       0.0
# 6      -2.0
# 7      -4.0
# 8       4.0
# 9       4.0
# 10      1.0
# 11      1.0
# 12     -6.0
# 13     -1.0
# 14     -3.0
# 15      0.0
# 16     -1.0
# 17      3.0
# 18      0.0
# 19      0.0
# 20      0.0
# 21     -7.0
# 22      4.0
# 23      0.0
# 24      0.0
# 25      1.0
# 26      0.0
# 27     -2.0
# 28     -2.0
# 29     -4.0
#        ...
# 5141    3.0
# 5142    1.0
# 5143    1.0
# 5144   -2.0
# 5145    0.0
# 5146    2.0
# 5147    0.0
# 5148    0.0
# 5149    1.0
# 5150    1.0
# 5151    2.0
# 5152    1.0
# 5153    0.0
# 5154    1.0
# 5155    1.0
# 5156    1.0
# 5157    1.0
# 5158    1.0
# 5159    1.0
# 5160    1.0
# 5161    2.0
# 5162    2.0
# 5163    0.0
# 5164   -5.0
# 5165    0.0
# 5166   -7.0
# 5167   -2.0
# 5168    0.0
# 5169    1.0
# 5170   -2.0
# Name: polarityScore, Length: 5171, dtype: float64

# %%
for i in range(0,5179):
    y[i]=y[i]/10
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-5d9c8f13d2d0> in <module>()
#       1 for i in range(0,5179):
# ----> 2     y[i]=y[i]/10
#
# IndexError: index 5171 is out of bounds for axis 0 with size 5171

# %%
# Fitting Linear Regression to the dataset 
from sklearn.linear_model import LinearRegression 
lin = LinearRegression() 

lin.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-7eb880fddc1a> in <module>()
#       3 lin = LinearRegression()
#       4
# ----> 5 lin.fit(X, y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
X=pd.DataFrame(X).fillna(0)

# %%
y=pd.DataFrame(y).fillna(0)

# %%
# Fitting Linear Regression to the dataset 
from sklearn.linear_model import LinearRegression 
lin = LinearRegression() 

lin.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visualising the Linear Regression results 
plt.scatter(X, y, color = 'blue') 

plt.plot(X, lin.predict(X), color = 'red') 
plt.title('Linear Regression') 
plt.xlabel('retweetCount') 
plt.ylabel('PolarityScore') 

plt.show()

# %%
# Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures 

poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(X) 

poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visualising the Polynomial Regression results 
plt.scatter(X, y, color = 'blue') 

plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red') 
plt.title('Sentiment') 
plt.xlabel('Retweets') 
plt.ylabel('Polarities') 

plt.show()

# %%
datas.head()
# Out:
#   Unnamed: 0  index                                               text  \
# 0          0    1.0  RT @RNTata2000: The governments bold implemen...
# 1          1    2.0  RT @OfficeOfRG: Fully prepared for demonetizat...
# 2          2    3.0  RT @RNTata2000: Some further thoughts on imple...
# 3          3    4.0  RT @OfficeOfRG: The Congress Party's Charter o...
# 4          4    5.0  RT @scotchism: Hahaha...cutest critique of dem...
#
#    retweetCount  polarityScore
# 0      1.000000            0.4
# 1      0.726112            0.1
# 2      0.484913            0.0
# 3      0.404642           -0.1
# 4      0.394004            0.1

# %%
# Predicting a new result with Polynomial Regression 
lin2.predict(poly.fit_transform(0.394004))
# Out:
# array([[-0.03494002]])

# %%
from sklearn.metrics import accuracy_score
def cal_accuracy(Y_test,Y_pred):
    print('Accuracy:',accuracy_score(Y_test,Y_pred)*100)

# %%
def splitdataset(datas):
    #seperating the target variable
    X=datas.values[:,3]
    Y=datas.values[:,4]
    X=X.reshape(-1,1)
    Y=Y.reshape(-1,1)
    X=pd.DataFrame(X).fillna(0)
    Y=pd.DataFrame(Y).fillna(0)

    #spliting the dataset into train and test
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=100)

    return X,Y,X_train,X_test,Y_train,Y_test

# %%
def predictions(X_test):
    #prediction on test with giniindex
    Y_pred=lin2.predict(poly.fit_transform(X_test))
    print('Predicted Values:')
    print(Y_pred)
    return Y_pred

# %%
X,Y,X_train,X_test,Y_train,Y_test=splitdataset(datas)

# %%
Y_pred=predictions(X_test)
# Out:
# Predicted Values:
# [[-0.01066846]
#  [-0.01074404]
#  [-0.01069363]
#  ...
#  [-0.01066846]
#  [-0.01066846]
#  [-0.01066846]]

# %%
type(Y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(Y_pred)
# Out:
# numpy.ndarray

# %%
datas.polarityScore
# Out:
# 0       4.0
# 1       1.0
# 2       0.0
# 3      -1.0
# 4       1.0
# 5       0.0
# 6      -2.0
# 7      -4.0
# 8       4.0
# 9       4.0
# 10      1.0
# 11      1.0
# 12     -6.0
# 13     -1.0
# 14     -3.0
# 15      0.0
# 16     -1.0
# 17      3.0
# 18      0.0
# 19      0.0
# 20      0.0
# 21     -7.0
# 22      4.0
# 23      0.0
# 24      0.0
# 25      1.0
# 26      0.0
# 27     -2.0
# 28     -2.0
# 29     -4.0
#        ...
# 5141    3.0
# 5142    1.0
# 5143    1.0
# 5144   -2.0
# 5145    0.0
# 5146    2.0
# 5147    0.0
# 5148    0.0
# 5149    1.0
# 5150    1.0
# 5151    2.0
# 5152    1.0
# 5153    0.0
# 5154    1.0
# 5155    1.0
# 5156    1.0
# 5157    1.0
# 5158    1.0
# 5159    1.0
# 5160    1.0
# 5161    2.0
# 5162    2.0
# 5163    0.0
# 5164   -5.0
# 5165    0.0
# 5166   -7.0
# 5167   -2.0
# 5168    0.0
# 5169    1.0
# 5170   -2.0
# Name: polarityScore, Length: 5171, dtype: float64

# %%
for i in range(0,5171):
    if(datas.polarityScore[i]<0):
        datas.sentiment[i]=-1
    elif(datas.polarityScore[i]>0):
        datas.sentiment[i]=1
    else:
        datas.sentiment[i]=0
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
datas.head()
# Out:
#   Unnamed: 0  index                                               text  \
# 0          0    1.0  RT @RNTata2000: The governments bold implemen...
# 1          1    2.0  RT @OfficeOfRG: Fully prepared for demonetizat...
# 2          2    3.0  RT @RNTata2000: Some further thoughts on imple...
# 3          3    4.0  RT @OfficeOfRG: The Congress Party's Charter o...
# 4          4    5.0  RT @scotchism: Hahaha...cutest critique of dem...
#
#    retweetCount  polarityScore sentiment
# 0        5170.0            4.0         1
# 1        3754.0            1.0         1
# 2        2507.0            0.0         0
# 3        2092.0           -1.0        -1
# 4        2037.0            1.0         1

# %%
X = datas.iloc[:, 3:5].values 
y = datas.iloc[:, 5].values 
X=pd.DataFrame(X).fillna(0)
y=pd.DataFrame(y).fillna(0)

# %%
for i in range(0,5171):
    X[0][i]=X[0][i]/5170
    X[1][i]=X[1][i]/10
X
# Out:
#              0     1
# 0     0.000193  0.04
# 1     0.000140  0.01
# 2     0.000094  0.00
# 3     0.000078 -0.01
# 4     0.000076  0.01
# 5     0.000073  0.00
# 6     0.000070 -0.02
# 7     0.000054 -0.04
# 8     0.000050  0.04
# 9     0.000050  0.04
# 10    0.000043  0.01
# 11    0.000041  0.01
# 12    0.000040 -0.06
# 13    0.000040 -0.01
# 14    0.000039 -0.03
# 15    0.000039  0.00
# 16    0.000038 -0.01
# 17    0.000036  0.03
# 18    0.000036  0.00
# 19    0.000035  0.00
# 20    0.000034  0.00
# 21    0.000034 -0.07
# 22    0.000033  0.04
# 23    0.000033  0.00
# 24    0.000032  0.00
# 25    0.000029  0.01
# 26    0.000025  0.00
# 27    0.000024 -0.02
# 28    0.000024 -0.02
# 29    0.000024 -0.04
# ...        ...   ...
# 5141  0.000000  0.03
# 5142  0.000000  0.01
# 5143  0.000000  0.01
# 5144  0.000000 -0.02
# 5145  0.000000  0.00
# 5146  0.000000  0.02
# 5147  0.000000  0.00
# 5148  0.000000  0.00
# 5149  0.000000  0.01
# 5150  0.000000  0.01
# 5151  0.000000  0.02
# ...

# %%
# Fitting Linear Regression to the dataset 
from sklearn.linear_model import LinearRegression 
lin = LinearRegression() 

lin.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures 

poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(X) 

poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visualising the Polynomial Regression results 
plt.scatter(X[0], y, color = 'blue')
plt.scatter(X[1],y,color='red')

plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'orange') 
plt.title('Sentiment') 
plt.xlabel('Variable') 
plt.ylabel('Polarities') 

plt.show()

# %%
plt.plot(y,X[0],y,X[0],'ob',
         y,X[1],y,X[1],'or')
plt.show()

# %%
plt.plot(X[0],y,X[0],y,'ob')
plt.title('RetweetCount v/s Sentiment')
plt.xlabel('RetweetCount')
plt.ylabel('Sentiment')
ax=plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.yticks([-1,0,1])
plt.show()

# %%
plt.plot(X[1],y,X[1],y,'ob')
plt.title('PolarityScore v/s Sentiment')
plt.xlabel('PolarityScore')
plt.ylabel('Sentiment')
ax=plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.yticks([-1,0,1])
plt.show()

# %%
plt.plot(X[1],X[0]*5170,X[1],X[0]*5170,'ob')
plt.title('PolarityScore v/s Retweets')
plt.xlabel('PolarityScore')
plt.ylabel('Retweets')
ax=plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.show()
